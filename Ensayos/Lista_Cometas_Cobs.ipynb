# %%
# Librerías
import requests
import pandas as pd

# %%
# Verificar la conexión a internet.
def verificar_conexion():
    try:
        requests.get("http://www.google.com", timeout=5)
        print('✅ Conectado a internet.')
        return True
    
    except requests.ConnectionError:
        print('🛑 Sin conexión a internet.')
        return False

# %%
# Conexión con la API de COBS

Link_cops_API = 'https://cobs.si/api/comet_list.api'
try: 
    if verificar_conexion():
        response = requests.get(Link_cops_API)

        if response.status_code == 200:
            content = response.json()
            print('✅ Base de datos actualizada.')

except requests.ConnectionError: 
    print(f'🛑 Se presentó un error al cargar la base de datos.\nError: {response.status_code}\n{response.content}')
# Out:
# 🛑 Sin conexión a internet.

# %%
Link_cops_API = 'https://cobs.si/api/comet.api?des=C/2023 A3'
response = requests.get(Link_cops_API)
pd.to_datetime(response.json()['object']['perihelion_date'])
# Out:
# Timestamp('2024-09-27 17:48:00')

# %%
# Conexión con la API de COBS
def Obtener_perihelio():
    try: 
        nombre_cometa = 'C/2023 A3'
        Link_cops_API = f'https://cobs.si/api/comet.api?des={nombre_cometa}'

        if verificar_conexion():
            response = requests.get(Link_cops_API)

            if response.status_code == 200:
                perihelio = pd.to_datetime(response.json()['object']['perihelion_date'])
                print('✅ Perihelio del cometa obtenido.')
                return perihelio
        
    except requests.ConnectionError:
        print(f'🛑 Se presentó un error al cargar la base de datos.\nError: {response.status_code}\n{response.content}')

Obtener_perihelio()
# Out:
# ✅ Conectado a internet.
# ✅ Perihelio del cometa obtenido.
# Timestamp('2024-09-27 17:48:00')

# %%
cometas_df = pd.DataFrame(content['objects'])
cometas_df
# Out:
#         id type          name                                fullname  \
# 0        1    N     P/2010 H2                       P/2010 H2 (Vales)
# 1        2    C  C/2014 UN271  C/2014 UN271 (Bernardinelli-Bernstein)
# 2        3    C    C/2020 PV6                  C/2020 PV6 (PANSTARRS)
# 3        4    A     A/2021 E4                               A/2021 E4
# 4        6    C     C/2021 G3                   C/2021 G3 (PANSTARRS)
# ...    ...  ...           ...                                     ...
# 2228  2562    N     P/2024 R3                   P/2024 R3 (PANSTARRS)
# 2229  2563    C     C/2024 R4                   C/2024 R4 (PANSTARRS)
# 2230  2564    P          484P                         484P/Spacewatch
# 2231  2565    P          485P                    485P/Sheppard-Tholen
# 2232  2566    P          486P                            486P/Leonard
#
#      mpc_name  icq_name component current_mag   perihelion_date  \
# 0     K10H020   P2010H2      None        14.0  2025-03-09 15:44
# 1     K14UR1N  2014UNR1      None        18.1  2031-01-17 03:51
# 2     K20P06V   2020PV6      None        24.9  2021-09-26 01:47
# 3     K21E040   A2021E4      None        22.4  2022-04-24 21:51
# 4     K21G030    2021G3      None        24.9  2021-10-17 20:18
# ...       ...       ...       ...         ...               ...
# 2228  K24R030   P2024R3      None        20.0  2024-05-17 00:25
# 2229  K24R040    2024R4      None        20.9  2027-10-26 12:38
# 2230     484P      0484      None        26.6  2028-03-10 22:56
# 2231     485P      0485      None        23.2  2023-08-24 20:11
# 2232     486P      0486      None        21.1  2025-04-03 20:26
#
#      perihelion_mag peak_mag peak_mag_date  is_observed  is_active
# 0              12.6     12.5    2025-04-09         True       True
# 1              16.0     15.8    2031-04-04         True       True
# 2              15.6     14.9    2021-08-05         True       True
# 3              20.1     19.8    2022-02-21        False       True
# 4              21.4     20.9    2022-01-31        False       True
# ...             ...      ...           ...          ...        ...
# 2228           21.1     19.9    2024-10-11        False       True
# 2229           16.3     16.1    2028-02-29        False       True
# 2230           19.9     19.7    2028-02-08        False       True
# 2231           22.4     21.5    2024-01-11        False       True
# 2232           20.5     19.5    2025-09-05        False       True
#
# [2233 rows x 14 columns]

# %%
lista_cometas_df = cometas_df[['name', 'fullname']]
lista_cometas_df.name[lista_cometas_df.fullname.str.contains('Halley')].values[0]
# Out:
# '1P'

# %%
'1P' not in lista_cometas_df['name'].to_list()
# Out:
# False

# %%
from pathlib import Path

titulo = 'C/2023 A3'

Path('Graficas', f'{titulo}.png')
# Out:
# WindowsPath('Graficas/C/2023 A3.png')

# %%
import os 
ruta = os.path.join('Graficas', 'C/2023 A3.png')
ruta
# Out:
# 'Graficas\\C/2023 A3.png'

# %%
ruta = os.path.join('Graficas', rf'{titulo}.png')
ruta, rf'{titulo}.png'
# Out:
# ('Graficas\\C/2023 A3.png', 'C/2023 A3.png')

# %%
from datetime import date
print(date.today())
# Out:
# 2024-10-01

# %%
try:
    content = [] 
    fecha_inicial = '1976-01-01 00:00'
    nombre_cometa = 'C/2023 A3'
    Link_cops_API_pagina_1 = f'https://cobs.si/api/obs_list.api?des={nombre_cometa}&format=json&from_date={fecha_inicial}&page=1&exclude_faint=False&exclude_not_accurate=False'

    if True:
        print(f'\n⌛ Conectando con la base de datos [COBS Observaciones].')
        response_pagina_1 = requests.get(Link_cops_API_pagina_1)

        if response_pagina_1.status_code == 200:
            content_pagina_1 = response_pagina_1.json()
            numero_de_paginas = int(content_pagina_1['info']['pages'])

            content.extend(content_pagina_1['objects'])

            for pagina in range(2, numero_de_paginas + 1):
                Link_cops_API_pagina = f'https://cobs.si/api/obs_list.api?des={nombre_cometa}&format=json&from_date={fecha_inicial}&page={pagina}&exclude_faint=False&exclude_not_accurate=False'
                response_pagina = requests.get(Link_cops_API_pagina)
                content_pagina = response_pagina.json()
                content.extend(content_pagina['objects'])

            print('✅ Base de datos actualizada [COBS Observaciones].')
        
except:
    print(f'🛑 Se presentó un error al cargar la base de datos.\nError: {response_pagina.status_code}\n{response_pagina.content}')
# Out:
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].

# %%
pd.DataFrame(content)
# Out:
#      type             obs_date  \
# 0       V  2024-12-13 16:55:00
# 1       C  2024-12-12 18:09:00
# 2       V  2024-12-12 08:52:47
# 3       V  2024-12-10 17:15:00
# 4       C  2024-12-10 17:14:00
# ...   ...                  ...
# 2419    C  2023-02-27 07:51:00
# 2420    C  2023-02-26 03:35:00
# 2421    C  2023-02-25 18:57:35
# 2422    C  2023-02-25 18:00:00
# 2423    C  2023-02-25 07:40:48
#
#                                                   comet  \
# 0     {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 1     {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 2     {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 3     {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 4     {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# ...                                                 ...
# 2419  {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 2420  {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 2421  {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 2422  {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
# 2423  {'type': 'C', 'name': 'C/2023 A3', 'fullname':...
#
#                                                observer  \
# 0     {'first_name': 'Jacek', 'last_name': 'Powichro...
# 1     {'first_name': 'Douglas', 'last_name': 'Heggie...
# 2     {'first_name': 'Osamu', 'last_name': 'Miyazaki...
# 3     {'first_name': 'Virgilio', 'last_name': 'Gonan...
# 4     {'first_name': 'Douglas', 'last_name': 'Heggie...
# ...                                                 ...
# 2419  {'first_name': 'John', 'last_name': 'Maikner',...
# 2420  {'first_name': 'Gideon', 'last_name': 'van Bui...
# 2421  {'first_name': 'Katsumi', 'last_name': 'Yoshim...
# 2422  {'first_name': 'Gideon', 'last_name': 'van Bui...
# 2423  {'first_name': 'Katsumi', 'last_name': 'Yoshim...
#
#                         location extinction  \
# 0                        Knyszyn       None
# 1         ASERO, Trevinca, Spain       None
# 2                           None          w
# 3                   Udine, Italy       None
# 4            Edinburgh, Scotland       None
# ...                          ...        ...
# 2419  Comet Hunter Observatory 2       None
# 2420         Dordrecht, NL (G06)       None
# 2421                        None       None
# 2422     Siding Spring, AU (Q62)       None
# 2423                        None       None
#
#                                              obs_method comet_visibility  \
# 0     {'key': 'B', 'name': 'Simple Out-Out method', ...             None
# 1     {'key': 'Z', 'name': 'CCD Visual equivalent', ...             None
# 2     {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 3     {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 4     {'key': 'Z', 'name': 'CCD Visual equivalent', ...             None
# ...                                                 ...              ...
# 2419  {'key': 'C', 'name': 'Unfiltered total CCD mag...             None
# 2420  {'key': 'C', 'name': 'Unfiltered total CCD mag...             None
# 2421  {'key': 'C', 'name': 'Unfiltered total CCD mag...             None
# 2422  {'key': 'C', 'name': 'Unfiltered total CCD mag...             None
# 2423  {'key': 'C', 'name': 'Unfiltered total CCD mag...             None
#
#      magnitude conditions  ... magnitude_error comparison_star_magnitude  \
# 0         10.3       None  ...            None                      None
# 1          9.2       None  ...            None                      None
# 2          9.4       None  ...            None                      None
# 3          9.5       None  ...            None                      None
# 4          9.1       None  ...            None                      None
# ...        ...        ...  ...             ...                       ...
# 2419      18.0       None  ...            None                      None
# 2420      18.1       None  ...            None                      None
# 2421      18.2       None  ...            None                     15.60
# 2422      17.9       None  ...            None                      None
# 2423      18.3       None  ...            None                     15.60
#
#      pixel_size_x  pixel_size_y  pixel_size_unit  \
# 0            None          None             None
# 1            None          None             None
# 2            None          None             None
# 3            None          None             None
# 4            None          None             None
# ...           ...           ...              ...
# 2419         None          None             None
# 2420         None          None             None
# 2421          2.0           2.0                s
# 2422         None          None             None
# 2423          0.7           0.7                s
#
#                            obs_comment obs_sky_quality obs_sky_quality_method  \
# 0                                                 None                    NaN
# 1     Limiting magnitude 18.34 (ASTAP)            None                    NaN
# 2                                                 None                    NaN
# 3                                                 None                    NaN
# 4     Limiting magnitude 16.15 (ASTAP)            None                    NaN
# ...                                ...             ...                    ...
# 2419                                              None                    NaN
# 2420                        Atik 460EX            None                    NaN
# 2421                                              None                    NaN
# 2422                                              None                    NaN
# 2423                                              None                    NaN
#
#      reference_star_names           date_added
# 0                          2024-12-13 17:14:27
# 1                          2024-12-13 18:22:13
# 2                          2024-12-13 04:37:47
# 3                          2024-12-10 17:55:30
# 4                          2024-12-12 17:04:51
# ...                   ...                  ...
# 2419                       2023-03-03 17:56:14
# 2420                       2023-03-07 16:11:04
# 2421                       2023-03-06 01:25:19
# 2422                       2023-03-07 16:09:51
# 2423                       2023-03-06 01:25:19
#
# [2424 rows x 47 columns]

# %%
pd.DataFrame(content['objects']).sort_values(by='obs_date')
# Out:
#      type             obs_date  \
# 2499    V  1986-03-17 18:14:24
# 2498    V  1986-03-17 18:28:47
# 2497    V  1986-03-17 18:43:12
# 2496    V  1986-03-17 19:12:00
# 2495    V  1986-03-17 19:12:00
# ...   ...                  ...
# 4       V  1991-03-15 04:47:59
# 3       V  1991-03-16 04:47:59
# 2       V  1991-03-17 04:47:59
# 1       V  1991-03-18 04:47:59
# 0       V  1991-04-12 00:00:00
#
#                                                   comet  \
# 2499  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2498  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2497  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2496  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2495  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# ...                                                 ...
# 4     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 3     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 1     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 0     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
#
#                                                observer location extinction  \
# 2499  {'first_name': 'T. B.', 'last_name': 'Tregaski...     None       None
# 2498  {'first_name': 'Terry', 'last_name': 'Lovejoy'...     None       None
# 2497  {'first_name': 'K.', 'last_name': 'Bryant', 'i...     None       None
# 2496  {'first_name': 'Ayumu', 'last_name': 'Kishi', ...     None       None
# 2495  {'first_name': 'Masahiko', 'last_name': 'Momos...     None       None
# ...                                                 ...      ...        ...
# 4     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 3     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 2     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 1     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 0     {'first_name': 'O.', 'last_name': 'Hainaut', '...     None       None
#
#                                              obs_method comet_visibility  \
# 2499    {'key': '-', 'name': 'Unknown', 'source': None}             None
# 2498  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 2497  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 2496  {'key': 'M', 'name': 'Modified-Out method', 's...             None
# 2495  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# ...                                                 ...              ...
# 4     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 3     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 2     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 1     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 0     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
#
#      magnitude conditions  ... magnitude_error comparison_star_magnitude  \
# 2499       3.1       None  ...            None                      None
# 2498       2.7       None  ...            None                      None
# 2497       3.6       None  ...            None                      None
# 2496       3.3       None  ...            None                      None
# 2495       3.0       None  ...            None                      None
# ...        ...        ...  ...             ...                       ...
# 4         19.1       None  ...            None                      None
# 3         19.1       None  ...            None                      None
# 2         19.1       None  ...            None                      None
# 1         19.3       None  ...            None                      None
# 0         22.0          :  ...            None                      None
#
#      pixel_size_x  pixel_size_y  pixel_size_unit obs_comment obs_sky_quality  \
# 2499         None          None             None                        None
# 2498         None          None             None                        None
# 2497         None          None             None                        None
# 2496         None          None             None                        None
# 2495         None          None             None                        None
# ...           ...           ...              ...         ...             ...
# 4            None          None             None                        None
# 3            None          None             None                        None
# 2            None          None             None                        None
# 1            None          None             None                        None
# 0            None          None             None                        None
#
#      obs_sky_quality_method reference_star_names           date_added
# 2499                    NaN                       2022-05-08 10:55:36
# 2498                    NaN                       2022-05-08 10:55:36
# 2497                    NaN                       2022-05-08 10:55:36
# 2496                    NaN                       2022-05-08 10:55:36
# 2495                    NaN                       2022-05-08 10:55:36
# ...                     ...                  ...                  ...
# 4                       NaN                       2022-05-08 10:33:31
# 3                       NaN                       2022-05-08 10:33:31
# 2                       NaN                       2022-05-08 10:33:30
# 1                       NaN                       2022-05-08 10:33:29
# 0                       NaN                       2022-05-08 10:33:25
#
# [2500 rows x 47 columns]

# %%
pages = content['info']['pages']

content_1 = conectar_con_API_de_COBS_Observaciones(1)
content_2 = conectar_con_API_de_COBS_Observaciones(2) 
content_3 = conectar_con_API_de_COBS_Observaciones(3)
# Out:
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
#
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
#
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].

# %%
page_1 = pd.DataFrame(content_1['objects'])
page_2 = pd.DataFrame(content_1['objects'])
page_3 = pd.DataFrame(content_1['objects'])

pd.concat([page_1, page_2, page_3])
# Out:
#      type             obs_date  \
# 0       V  1991-04-12 00:00:00
# 1       V  1991-03-18 04:47:59
# 2       V  1991-03-17 04:47:59
# 3       V  1991-03-16 04:47:59
# 4       V  1991-03-15 04:47:59
# ...   ...                  ...
# 2495    V  1986-03-17 19:12:00
# 2496    V  1986-03-17 19:12:00
# 2497    V  1986-03-17 18:43:12
# 2498    V  1986-03-17 18:28:47
# 2499    V  1986-03-17 18:14:24
#
#                                                   comet  \
# 0     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 1     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 3     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 4     {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# ...                                                 ...
# 2495  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2496  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2497  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2498  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
# 2499  {'type': 'P', 'name': '1P', 'fullname': '1P/Ha...
#
#                                                observer location extinction  \
# 0     {'first_name': 'O.', 'last_name': 'Hainaut', '...     None       None
# 1     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 2     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 3     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# 4     {'first_name': 'Richard M.', 'last_name': 'Wes...     None       None
# ...                                                 ...      ...        ...
# 2495  {'first_name': 'Masahiko', 'last_name': 'Momos...     None       None
# 2496  {'first_name': 'Ayumu', 'last_name': 'Kishi', ...     None       None
# 2497  {'first_name': 'K.', 'last_name': 'Bryant', 'i...     None       None
# 2498  {'first_name': 'Terry', 'last_name': 'Lovejoy'...     None       None
# 2499  {'first_name': 'T. B.', 'last_name': 'Tregaski...     None       None
#
#                                              obs_method comet_visibility  \
# 0     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 1     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 2     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 3     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# 4     {'key': 'V', 'name': 'Johnson/Bessel/Kron/Cous...             None
# ...                                                 ...              ...
# 2495  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 2496  {'key': 'M', 'name': 'Modified-Out method', 's...             None
# 2497  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 2498  {'key': 'S', 'name': 'In-Out method', 'source'...             None
# 2499    {'key': '-', 'name': 'Unknown', 'source': None}             None
#
#      magnitude conditions  ... magnitude_error comparison_star_magnitude  \
# 0         22.0          :  ...            None                      None
# 1         19.3       None  ...            None                      None
# 2         19.1       None  ...            None                      None
# 3         19.1       None  ...            None                      None
# 4         19.1       None  ...            None                      None
# ...        ...        ...  ...             ...                       ...
# 2495       3.0       None  ...            None                      None
# 2496       3.3       None  ...            None                      None
# 2497       3.6       None  ...            None                      None
# 2498       2.7       None  ...            None                      None
# 2499       3.1       None  ...            None                      None
#
#      pixel_size_x  pixel_size_y  pixel_size_unit obs_comment obs_sky_quality  \
# 0            None          None             None                        None
# 1            None          None             None                        None
# 2            None          None             None                        None
# 3            None          None             None                        None
# 4            None          None             None                        None
# ...           ...           ...              ...         ...             ...
# 2495         None          None             None                        None
# 2496         None          None             None                        None
# 2497         None          None             None                        None
# 2498         None          None             None                        None
# 2499         None          None             None                        None
#
#      obs_sky_quality_method reference_star_names           date_added
# 0                       NaN                       2022-05-08 10:33:25
# 1                       NaN                       2022-05-08 10:33:29
# 2                       NaN                       2022-05-08 10:33:30
# 3                       NaN                       2022-05-08 10:33:31
# 4                       NaN                       2022-05-08 10:33:31
# ...                     ...                  ...                  ...
# 2495                    NaN                       2022-05-08 10:55:36
# 2496                    NaN                       2022-05-08 10:55:36
# 2497                    NaN                       2022-05-08 10:55:36
# 2498                    NaN                       2022-05-08 10:55:36
# 2499                    NaN                       2022-05-08 10:55:36
#
# [7500 rows x 47 columns]
