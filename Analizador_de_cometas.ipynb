# %%
# Librerías
import pandas as pd
import plotly.graph_objects as go

# Módulos
from Funciones.Buscar_cometa import buscar_cometa
from Funciones.Envolvente_superior_inferior import envolvente_superior_inferior
from Funciones.Envolvente_superior_inferior_archivos import envolvente_superior_inferior_archivos
from Funciones.Generar_grafica import generar_grafica

# %%
# Panel de control
nombre_del_cometa = '3I'
fecha_inicial = '1990-06-01'

# %%
buscar_cometa(nombre_del_cometa)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Coincidencias halladas:
#
# ['3I']

# %%
# Base de datos
bases_de_datos_cobs = envolvente_superior_inferior(nombre_del_cometa, fecha_inicial)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Cometa hallado: 3I
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
# ⌛ Conectando con la base de datos [MPC efemerides].
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\erfa\core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 163 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\erfa\core.py:133: ErfaWarning: ERFA function "d2dtf" yielded 163 of "dubious year (Note 5)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# ✅ Base de datos actualizada [MPC efemerides].
# ⌛ Conectando con la base de datos [COBS].
# ✅ Perihelio del cometa obtenido.

# %%
tipo_de_grafica = '1' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos_cobs)

# %%
# Cargar archivo con los datos del MPC
datos_mpc_df = pd.read_parquet('Archivos/2525_OStein_MPC.parquet')
datos_mpc_df
# Out:
#        obs_date  magnitude
# 0    1939-02-21      14.40
# 1    1953-09-07      14.40
# 2    1959-10-29      15.60
# 3    1959-10-29      15.60
# 4    1959-10-29      15.60
# ...         ...        ...
# 6988 2025-05-24      16.14
# 6989 2025-05-24      16.47
# 6990 2025-05-24      16.43
# 6991 2025-05-24      16.40
# 6992 2025-05-24      16.45
#
# [6993 rows x 2 columns]

# %%
# bases_de_datos_mpc =  envolvente_superior_inferior_archivos(nombre_del_cometa, datos_mpc_df)
bases_de_datos_mpc =  envolvente_superior_inferior_archivos('3I', datos_mpc_df)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [MPC efemerides].
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\erfa\core.py:133: ErfaWarning:
#
# ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\erfa\core.py:133: ErfaWarning:
#
# ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
#
# c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\erfa\core.py:133: ErfaWarning:
#
# ERFA function "dtf2d" yielded 1441 of "dubious year (Note 6)"
# ---------------------------------------------------------------------------
# IllegalSecondError                        Traceback (most recent call last)
# Cell In[13], line 2
#       1 # bases_de_datos_mpc =  envolvente_superior_inferior_archivos(nombre_del_cometa, datos_mpc_df)
# ----> 2 bases_de_datos_mpc =  envolvente_superior_inferior_archivos('3I', datos_mpc_df)
#
# File c:\Users\USER\Documents\Udea\Python\Analizador_de_cometas_COLAB\Funciones\Envolvente_superior_inferior_archivos.py:29, in envolvente_superior_inferior_archivos(nombre_cometa, curva_de_luz_cruda_df, perihelio)
#      15 '''
#      16 Procesa los datos del cometa especificado para calcular la
#      17 envolvente inferior de la curva de luz del cometa especificado.
#    (...)     22 [4] curva_de_luz_interna_df.
#      23 '''
#      25 if verificar_conexion():
#      26
#      27     # Conexión con la API del MPC
#      28     # ephemeris = descargar_efemerides(nombre_cometa, curva_de_luz_cruda_df)
# ---> 29     ephemeris = conectar_con_API_de_MPC(curva_de_luz_cruda_df, nombre_cometa)
#      31     # Obtener perihelio de la API de COBS
#      32     if type(perihelio) == None:
#
# File c:\Users\USER\Documents\Udea\Python\Analizador_de_cometas_COLAB\Funciones\Conectar_con_API_de_MPC.py:14, in conectar_con_API_de_MPC(curva_de_luz_cruda_df, nombre_cometa)
#      12 print('⌛ Conectando con la base de datos [MPC efemerides].')
#      13 for i in range(ceil(fechas/1441)):
# ---> 14     efemerides = MPC.get_ephemeris(nombre_cometa, start = str(fecha_inicial), number = 1441)
#      15     efemerides_ciclo_df = efemerides.to_pandas()
#      16     efemerides_total.append(efemerides_ciclo_df)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astroquery\utils\class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astroquery\utils\process_asyncs.py:29, in async_to_sync.<locals>.create_method.<locals>.newmethod(self, *args, **kwargs)
#      27 if kwargs.get('get_query_payload') or kwargs.get('field_help'):
#      28     return response
# ---> 29 result = self._parse_result(response, verbose=verbose)
#      30 self.table = result
#      31 return result
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astroquery\mpc\core.py:1152, in MPCClass._parse_result(self, result, **kwargs)
#    1150 # convert from MPES string:
#    1151 ra = Angle(tab['RA'], unit='hourangle').to('deg')
# -> 1152 dec = Angle(tab['Dec'], unit='deg')
#    1154 # optionally convert back to a string
#    1155 if self._ra_format is not None:
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\coordinates\angles\core.py:185, in Angle.__new__(cls, angle, unit, dtype, copy, **kwargs)
#     183 elif isinstance(angle, np.ndarray):
#     184     if angle.dtype.kind in "SUVO":
# --> 185         angle = [cls(x, unit, copy=COPY_IF_NEEDED) for x in angle]
#     187 elif hasattr(angle, "__array__") and (
#     188     not hasattr(angle, "dtype") or angle.dtype.kind not in "SUVO"
#     189 ):
#     190     angle = np.asarray(angle)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\coordinates\angles\core.py:174, in Angle.__new__(cls, angle, unit, dtype, copy, **kwargs)
#     172 a = np.abs(angle[0]) + angle[1] / 60.0
#     173 if len(angle) == 3:
# --> 174     formats._check_second_range(angle[2])
#     175     a += angle[2] / 3600.0
#     177 angle = np.copysign(a, angle[0])
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\astropy\coordinates\angles\formats.py:323, in _check_second_range(sec)
#     321 if not 0.0 <= sec < 60.0:
#     322     if sec != 60.0:
# --> 323         raise IllegalSecondError(sec)
#     324     warn(IllegalSecondWarning(sec, "Treating as 0 sec, +1 min"))
#
# IllegalSecondError: An invalid value for 'second' was found ('311'); should be in the range [0,60).

# %%
tipo_de_grafica = '7' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos_mpc)

# %%
tipo_de_grafica = '7' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos_mpc)

# %%
bases_de_datos_mpc[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 bases_de_datos_mpc[1]
#
# NameError: name 'bases_de_datos_mpc' is not defined

# %%
# curva_cruda_cobs_df = bases_de_datos_cobs[1]
# envolvente_cobs_df = bases_de_datos_cobs[2] 
# nucleo_cobs_df = bases_de_datos_cobs[3]

curva_reducida_mpc_df = bases_de_datos_mpc[1] 
envolvente_mpc_df = bases_de_datos_mpc[2] 
nucleo_mpc_df = bases_de_datos_mpc[3]

# %%
fig = go.Figure()
    
# fig.add_trace(go.Scatter(x=curva_cruda_cobs_df.obs_date, 
#         y=curva_cruda_cobs_df.magnitud_reducida, mode='markers',
#         name='Cruda_Cobs', 
#         marker=dict(color='#fa04f6', line=dict(width=1, color='DarkSlateGrey'))))

# fig.add_trace(go.Scatter(x=envolvente_cobs_df.obs_date, 
#         y=envolvente_cobs_df.promedio_movil, mode='markers',
#         name='Envolvente_Cobs', 
#         marker=dict(color='yellow', line=dict(width=1, color='DarkSlateGrey'))))

# fig.add_trace(go.Scatter(x=nucleo_cobs_df.obs_date, 
#         y=nucleo_cobs_df.promedio_movil, mode='markers',
#         name='Nucleo_Cobs', 
#         marker=dict(color='red', line=dict(width=1, color='DarkSlateGrey'))))

fig.add_trace(go.Scatter(x=curva_reducida_mpc_df.delta_t, 
        y=curva_reducida_mpc_df.magnitud_reducida, mode='markers',
        name='Reducida_MPC', 
        marker=dict(color='#04ebfa', line=dict(width=1, color='DarkSlateGrey'))))

fig.add_trace(go.Scatter(x=envolvente_mpc_df.delta_t, 
        y=envolvente_mpc_df.promedio_movil, mode='markers',
        name='Envolvente_MPC', 
        marker=dict(color= '#fa7004 ', line=dict(width=1, color='DarkSlateGrey'))))

fig.add_trace(go.Scatter(x=nucleo_mpc_df.delta_t, 
        y=nucleo_mpc_df.promedio_movil, mode='markers',
        name='Nucleo_MPC', 
        marker=dict(color='#fa045b', line=dict(width=1, color='DarkSlateGrey'))))

fig.update_layout(template='plotly_dark')
fig.update_yaxes(autorange="reversed")
fig.update_layout(template='plotly_dark', xaxis_title='t - Tq [d]', yaxis_title=r'm(1,1,0)', title = f'Lightcurve of comet {nombre_del_cometa}')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 18
#       1 fig = go.Figure()
#       3 # fig.add_trace(go.Scatter(x=curva_cruda_cobs_df.obs_date,
#       4 #         y=curva_cruda_cobs_df.magnitud_reducida, mode='markers',
#       5 #         name='Cruda_Cobs',
#    (...)     15 #         name='Nucleo_Cobs',
#      16 #         marker=dict(color='red', line=dict(width=1, color='DarkSlateGrey'))))
# ---> 18 fig.add_trace(go.Scatter(x=curva_reducida_mpc_df.delta_t,
#      19         y=curva_reducida_mpc_df.magnitud_reducida, mode='markers',
#      20         name='Reducida_MPC',
#      21         marker=dict(color='#04ebfa', line=dict(width=1, color='DarkSlateGrey'))))
#      23 fig.add_trace(go.Scatter(x=envolvente_mpc_df.delta_t,
#      24         y=envolvente_mpc_df.promedio_movil, mode='markers',
#      25         name='Envolvente_MPC',
#      26         marker=dict(color='#fa7004 ', line=dict(width=1, color='DarkSlateGrey'))))
#      28 fig.add_trace(go.Scatter(x=nucleo_mpc_df.delta_t,
#      29         y=nucleo_mpc_df.promedio_movil, mode='markers',
#      30         name='Nucleo_MPC',
#      31         marker=dict(color='#fa045b', line=dict(width=1, color='DarkSlateGrey'))))
#
# NameError: name 'curva_reducida_mpc_df' is not defined
