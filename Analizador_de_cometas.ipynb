# %%
# Librerías
from Funciones.Buscar_cometa import buscar_cometa
from Funciones.Envolvente_superior_inferior import envolvente_superior_inferior
from Funciones.Generar_grafica import generar_grafica

# %%
# Panel de control
nombre_del_cometa = '2P'
fecha_inicial = '1990-06-01'

# %%
buscar_cometa(nombre_del_cometa)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Coincidencias halladas:
#
# ['62P' '2P' '22P' '82P' '142P' '152P' '162P' '202P' '232P' '172P' '242P'
#  '32P' '102P' '12P' '52P' '72P' '92P' '112P' '122P' '132P' '182P' '192P'
#  '212P' '222P' '252P' '42P' '262P' '272P' '282P' '292P' '302P' '312P'
#  '322P' '332P' '332P-A' '332P-B' '332P-C' '332P-D' '332P-E' '332P-F'
#  '332P-G' '332P-H' '332P-I' '332P-J' '342P' '352P' '362P' '372P' '382P'
#  '392P' '402P' '412P' '422P' '432P' '442P' '452P' '462P' '472P' '482P'
#  '492P']

# %%
# Base de datos
bases_de_datos = envolvente_superior_inferior(nombre_del_cometa, fecha_inicial)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Cometa hallado: 2P
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
# ⌛ Conectando con la base de datos [MPC efemerides].
# ✅ Base de datos actualizada [MPC efemerides].
# ⌛ Conectando con la base de datos [COBS].
# ✅ Perihelio del cometa obtenido.

# %%
tipo_de_grafica = '7' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos)

# %%
bases_de_datos[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 615 entries, 4 to 618
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   obs_date           615 non-null    datetime64[ns]
#  1   obs_method_key     615 non-null    object
#  2   magnitude          615 non-null    float64
#  3   index              615 non-null    int64
#  4   delta              615 non-null    float64
#  5   r                  615 non-null    float64
#  6   phase              615 non-null    float64
#  7   magnitud_reducida  615 non-null    float64
#  8   delta_t            615 non-null    int64
#  9   promedio_movil     615 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 52.9+ KB
