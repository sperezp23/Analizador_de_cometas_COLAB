# %%
# Librerías
from Funciones.Envolvente_inferior import envolvente_inferior
from Funciones.Generar_grafica import generar_grafica

# %%
# Panel de control
nombre_del_cometa = 'C/2023 A3'

# %%
# creación de las bases de datos
curva_de_luz_cruda_df, curva_de_luz_procesada_df, curva_de_luz_interna_df = envolvente_inferior(nombre_del_cometa,True)
# Out:
# ✅ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
# ✅ Conectando con la base de datos [MPC efemerides].
# ✅ Base de datos actualizada [MPC efemerides].

# %%
generar_grafica('4', nombre_del_cometa, curva_de_luz_interna_df)

# %%
# Curva de luz cruda
curva_de_luz_cruda(nombre_del_cometa, curva_de_luz_cruda_df, 'envolvente_inferior')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Curva de luz cruda
# ----> 2 curva_de_luz_cruda(nombre_del_cometa, curva_de_luz_cruda_df, 'envolvente_inferior')
#
# NameError: name 'curva_de_luz_cruda' is not defined

# %%
# Curva de luz reducida
curva_de_luz_reducida(nombre_del_cometa, curva_de_luz_procesada_df, 'envolvente_inferior')

# %%
# Curva de luz interna
curva_de_luz_interna(nombre_del_cometa, curva_de_luz_interna_df, 'envolvente_inferior')

# %%
# Curva de luz interna promediada
curva_de_luz_interna_promediada(nombre_del_cometa, curva_de_luz_interna_df, 'envolvente_inferior')
