# %%
# Librerías
from Funciones.Buscar_cometa import buscar_cometa
from Funciones.Envolvente_superior_inferior import envolvente_superior_inferior
from Funciones.Generar_grafica import generar_grafica

# %%
# Panel de control
nombre_del_cometa = '12P'
fecha_inicial = '1990-06-01'

# %%
buscar_cometa(nombre_del_cometa)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Coincidencias halladas:
#
# ['12P' '112P' '212P' '312P' '412P']

# %%
# Base de datos
bases_de_datos = envolvente_superior_inferior(nombre_del_cometa, fecha_inicial)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Cometa hallado: 12P
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
# ⌛ Conectando con la base de datos [MPC efemerides].
# ✅ Base de datos actualizada [MPC efemerides].
# ⌛ Conectando con la base de datos [COBS].
# ✅ Perihelio del cometa obtenido.

# %%
tipo_de_grafica = '7' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos)

# %%
bases_de_datos[2].sample(10)
# Out:
#       obs_date obs_method_key  magnitude  index  delta      r  phase  \
# 232 2024-01-28              D        7.7    601  1.959  1.646   30.1
# 227 2024-01-23              C        9.0    596  2.011  1.712   29.3
# 324 2024-04-30              M        4.7    694  1.596  0.799   31.7
# 433 2024-09-08              C       10.6    825  2.749  2.362   21.0
# 199 2023-12-25              Z        9.8    567  2.340  2.089   24.8
# 239 2024-02-04              C        7.7    608  1.889  1.553   31.4
# 445 2025-02-07              Z       17.2    977  4.429  4.050   12.3
# 13  2023-03-18              C       18.8    285  5.319  5.081   10.7
# 171 2023-11-27              S        8.9    539  2.644  2.439   21.9
# 123 2023-10-01              C       11.5    482  3.105  3.107   18.6
#
#      magnitud_reducida  delta_t  promedio_movil
# 232           5.157679      -85        5.358588
# 227           6.315421      -90        5.386592
# 324           4.172102        8        4.070854
# 433           6.537727      139        6.760938
# 199           6.354229     -119        6.247085
# 239           5.362983      -78        4.992152
# 445          10.931196      291        9.843293
# 13           11.641104     -401       11.469259
# 171           4.852634     -147        4.838773
# 123           6.577986     -204        8.021117
