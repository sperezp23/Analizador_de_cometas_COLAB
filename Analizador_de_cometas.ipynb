# %%
# Librerías
from Funciones.Buscar_cometa import buscar_cometa
from Funciones.Envolvente_superior_inferior import envolvente_superior_inferior
from Funciones.Generar_grafica import generar_grafica

# %%
# Panel de control
nombre_del_cometa = '1P'

# %%
buscar_cometa(nombre_del_cometa)
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Coincidencias halladas:
#
# ['421P' '31P' '61P' '81P' '131P' '141P-A' '211P' '231P' '111P' '241P'
#  '91P' '41P' '71P' '161P' '21P' '1P' '11P' '51P' '101P' '121P' '151P'
#  '171P' '181P' '191P' '201P' '221P' '141P' '251P' '261P' '271P' '281P'
#  '291P' '301P' '311P' '51P-D' '321P' '51P-A' '51P-B' '51P-C' '101P-A'
#  '141P-B' '141P-C' '331P' '341P' '351P' '361P' '371P' '381P' '391P'
#  '101P-B' '401P' '411P' '431P' '441P' '141P-I' '451P' '461P' '471P' '481P'
#  '491P']

# %%
# Base de datos
bases_de_datos = envolvente_superior_inferior(nombre_del_cometa, '1985-01-01')
# Out:
# ✅ Conectado a internet.
# ----------------------------------------
# ⌛ Conectando con la base de datos [COBS lista de Cometas].
# ✅ Base de datos actualizada [COBS lista de Cometas].
# ✅ Cometa hallado: 1P
#
# ⌛ Conectando con la base de datos [COBS Observaciones].
# ✅ Base de datos actualizada [COBS Observaciones].
# ⌛ Conectando con la base de datos [MPC efemerides].
# ✅ Base de datos actualizada [MPC efemerides].
# ✅ Perihelio del cometa obtenido.

# %%
tipo_de_grafica = '7' 
generar_grafica(tipo_de_grafica, nombre_del_cometa, bases_de_datos)

# %%
bases_de_datos[1].sort_values(by='obs_date')
# Out:
#      obs_method_key   obs_date  magnitude  delta      r  phase  \
# 6577              I 1985-01-23       19.6  4.281  5.040    7.7
# 6576              V 1985-02-16       19.9  4.412  4.814   11.2
# 6575              - 1985-02-16       18.0  4.412  4.814   11.2
# 6574              V 1985-02-17       19.4  4.420  4.804   11.3
# 6573              V 1985-02-17       19.5  4.420  4.804   11.3
# ...             ...        ...        ...    ...    ...    ...
# 4                 S 1988-02-23       16.5  7.090  8.027    2.4
# 3                 g 1988-03-15       18.2  7.299  8.177    3.5
# 2                 V 1988-04-10       17.5  7.735  8.361    5.6
# 1                 V 1988-04-19       17.6  7.920  8.424    6.1
# 0                 V 1988-05-15       17.7  8.507  8.605    6.7
#
#       magnitud_reducida  delta_t
# 6577           7.330121   -27986
# 6576           6.864292   -27962
# 6575           7.964292   -27962
# 6574           7.664874   -27961
# 6573           6.464874   -27961
# ...                 ...      ...
# 4             10.324003   -26860
# 3             10.220713   -26839
# 2             10.046407   -26813
# 1             10.178782   -26804
# 0             12.677363   -26778
#
# [6578 rows x 8 columns]
